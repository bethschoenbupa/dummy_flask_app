# %%
import requests
import time
from pprint import pprint
from datetime import datetime, timedelta

# %% [markdown]
# # API v1 Demo
# Beneficial for stakeholders to view an example output from the app without having to disect the code/run the app themselves. They may also be interested in viewing runtimes too.

# %% [markdown]
# ## Birthday Haiku
# Given a person and date, determine whether it's the person's birthday. Write a Haiku depending on whether it's their birthday?
#
# #### `shadow_mode = True`

# %%
name = "Beth"
today = datetime.today()
birthday =today.strftime("%Y-%m-%d")

body = {
    "userInfo": {
        "name":name,
        "date":birthday
    }
}
url = f'http://localhost:5000/api/v1/birthdayhaiku'
start = time.time()
x = requests.post(url, json=body, headers={"X-Shadow-Mode": "true"})
end = time.time()

time_elapsed = end-start
print(f"Time elapsed: {time_elapsed}s")

result = x.json()

pprint(result)

# %% [markdown]
# #### `isBirthday = True`

# %%
name = "Beth"
today = datetime.today()
birthday =today.strftime("%Y-%m-%d")

body = {
    "userInfo": {
        "name":name,
        "date":birthday
    }
}

url = f'http://localhost:5000/api/v1/birthdayhaiku'
start = time.time()
x = requests.post(url, json=body)
end = time.time()

time_elapsed = end-start
print(f"Time elapsed: {time_elapsed}s")

result = x.json()

pprint(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /anaconda/envs/cs_venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /anaconda/envs/cs_venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %% [markdown]
# #### Second attempt (caching)

# %%
name = "Beth"
today = datetime.today()
birthday =today.strftime("%Y-%m-%d")

body = {
    "userInfo": {
        "name":name,
        "date":birthday
    }
}

url = f'http://localhost:5000/api/v1/birthdayhaiku'
start = time.time()
x = requests.post(url, json=body)
end = time.time()

time_elapsed = end-start
print(f"Time elapsed: {time_elapsed}s")

result = x.json()

pprint(result)

# %% [markdown]
# #### `isBirthday = False`

# %%
name = "Vasiliki"
yesterday = datetime.today() - timedelta(days=1)
birthday = yesterday.strftime("%Y-%m-%d")

body = {
    "name":name,
    "date":birthday
}

url = f'http://localhost:5000/api/v1/birthdayhaiku'
start = time.time()
x = requests.post(url, json=body)
end = time.time()

time_elapsed = end-start
print(f"Time elapsed: {time_elapsed}s")

result = x.json()

pprint(result)
